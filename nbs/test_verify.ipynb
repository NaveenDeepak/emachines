# %% [raw]
# ---
# {}
#
# ---

# %%
#| default_exp test_verify

#| export
def test_function(x: int) -> int:
    """Simple test function."""
    return x * 2

# %%
# Verify it works
result = test_function(5)
assert result == 10
print(f"✓ Success! {result}")
# Out:
# ✓ Success! 10
