# %% [raw]
# ---
# output-file: 02_motors_api.html
# title: Motors Public API
# ---

# %% [markdown]
# ## Overview
#
# Re-exports the full public API for `emachines.motors`.
#
# Importing from `emachines.motors` gives access to all public symbols without needing to know which submodule they live in.

# %% [markdown]
# ## Usage
#
# ```python
# from emachines.motors import *
# # or selectively:
# from emachines.motors import GeometricParams
# from emachines.motors import PMSMParams
# ```

# %%
#| default_exp motors.__init__
#| export
from emachines.motors.dc_motor import GeometricParams, MaterialProperties, OperatingConditions, LumpedParams, calculate_carter_coefficient, calculate_magnetic_circuit
from emachines.motors.pmsm import PMSMParams, back_emf, torque, dq_currents, SPM

__all__ = ['GeometricParams', 'MaterialProperties', 'OperatingConditions', 'LumpedParams', 'calculate_carter_coefficient', 'calculate_magnetic_circuit', 'PMSMParams', 'back_emf', 'torque', 'dq_currents', 'SPM']
