# %% [raw]
# ---
# output-file: module_name.html
# title: Module Name
#
# ---

# %% [markdown]
# ## Overview
#
# > **One-sentence description of what this module computes and why it matters.**
#
# <!-- Replace this block with a brief description of the physical or mathematical
#      problem this notebook addresses. Aim for 2-4 sentences. -->
#
# ### Why It Matters
# <!-- Explain the engineering motivation. What decision does this enable?
#      What would go wrong without this calculation? -->
#
# ### How It Fits Into Motor Design
# <!-- Describe where this module sits in the broader emachines workflow.
#      Which notebooks feed into this one? Which notebooks consume its outputs? -->
#
# ```
# emachines workflow:
#   xx_dependency.ipynb  →  [THIS NOTEBOOK]  →  xx_consumer.ipynb
# ```

# %% [markdown]
# ## Inputs and Outputs
#
# ### What You Provide
#
# | Parameter | Symbol | Description | Units | Typical Range |
# |-----------|--------|-------------|-------|---------------|
# | param_1   | $x$    | Description | unit  | range         |
# | param_2   | $y$    | Description | unit  | range         |
#
# ### What You Get
#
# | Result   | Symbol | Meaning |
# |----------|--------|---------|
# | result_1 | $z$    | Description and typical use |
#
# ### Example
# ```python
# from emachines.XX_module_name import my_function
# result = my_function(param_1=..., param_2=...)
# ```

# %% [markdown]
# ## Connections to Other Notebooks
#
# **Feeds into:**
# - `XX_notebook.ipynb` — explain how
#
# **Depends on:**
# - `XX_notebook.ipynb` — explain what is imported
#
# **Dependencies (Python):**
# - None  <!-- or list: numpy, scipy, etc. -->

# %% [markdown]
# ## Notation
#
# | Symbol | Definition | Units |
# |--------|-----------|-------|
# | $x$    | Description | SI unit |
# | $y$    | Description | SI unit |

# %% [markdown]
# ## Imports and Setup

# %%
#| default_exp XX_module_name
#| export
from __future__ import annotations

import numpy as np
# add further imports here

# %% [markdown]
# ## [Section 1: Descriptive Name]
#
# ### Theory
#
# <!-- Write the physics/math here, immediately before the implementation.
#      Use LaTeX for equations. Explain every symbol used. -->
#
# **Equation:**
# $$
# z = f(x, y)
# $$
#
# where:
# - $x$ = description
# - $y$ = description
#
# **Physical meaning:** <!-- What does this equation represent in the machine? -->
#
# **Design insight:** <!-- When is this large/small? What does it imply? -->

# %%
#| export
def my_function(
    param_1: float,
    param_2: float,
) -> float:
    """
    One-line summary.

    Longer description if needed — link to the theory above.

    Parameters
    ----------
    param_1 : float
        Description. Units.
    param_2 : float
        Description. Units.

    Returns
    -------
    float
        Description. Units. Range.

    Examples
    --------
    >>> my_function(1.0, 2.0)
    3.0
    """
    return param_1 + param_2  # replace with real implementation

# %% [markdown]
# ### Example: [Descriptive Title]
#
# <!-- Concrete, runnable example with real numbers. Show what the result means
#      physically. Vary one parameter to build intuition. -->

# %%
# Example: demonstrate my_function with a realistic scenario
result = my_function(1.0, 2.0)
print(f"Result: {result:.4f}")
print(f"Interpretation: ...")  # explain what this number means

# %% [markdown]
# ## [Section 2: Next Concept] *(repeat Theory → Implementation → Example pattern)*
#
# <!-- Copy the pattern above for each additional function or concept.
#      Keep theory immediately adjacent to its implementation. -->

# %% [markdown]
# ## References
#
# <!-- Cite every equation or dataset used. Use the format below. -->
#
# 1. Author, A. (Year). *Book or Paper Title*. Publisher. Chapter X, Eq. Y.
# 2. Author, B. & Author, C. (Year). "Paper Title." *Journal*, Vol(Issue), pp. XX–YY.
#    DOI: [10.xxxx/xxxxx](https://doi.org/10.xxxx/xxxxx)
# 3. Online resource: [Name](URL) — accessed YYYY-MM-DD.
#
# > **Rule:** Every equation in this notebook must have a corresponding reference entry.

# %% [markdown]
# ## Tests
#
# <!-- All test cells are marked `#| hide` so they run during `nbdev-test`
#      but are excluded from the generated documentation.
#
#      Test requirements:
#      - Every exported function must have at least one test
#      - Test edge cases: zero, negative, boundary values
#      - Validate against known analytical results where possible
#      - Each assert must have a descriptive failure message -->

# %%
#| hide
import numpy as np

# ── Test: [function name] ─────────────────────────────────────────────
# Basic correctness
result = my_function(1.0, 2.0)
assert result == 3.0, f"Expected 3.0, got {result}"
print("✓ my_function basic")

# Edge case: zero input
result_zero = my_function(0.0, 0.0)
assert result_zero == 0.0, f"Zero input: expected 0.0, got {result_zero}"
print("✓ my_function zero input")

# Physical validation: result must be positive for positive inputs
assert my_function(1.0, 1.0) > 0, "Result must be positive for positive inputs"
print("✓ my_function positivity")

print("\n✓ All [module name] tests passed")
